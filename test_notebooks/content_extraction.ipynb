# %%
import os
os.chdir("..")
import json, zipfile
import pandas as pd
from contentcreatie.config.settings import Settings 
from utils import *
from utils.content_extraction_utils import *
import tqdm
settings = Settings()
# Out:
# StorageService: No Connection String found. Attempting DefaultAzureCredential...
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/kis-compute-web/code/Users/a.melzer/Contentcreatie

# %% [markdown]
# # Extract content geel into dataframe

# %%
html_docs = get_all_html_docs(file_name="content_tridion.zip")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6782/6782 [00:29<00:00, 227.69it/s
# ...

# %%
extracted_df = pd.DataFrame(html_docs.values())
extracted_df['km_nummer'] = extracted_df['id']
print(f"Extracted {len(extracted_df)} documents")
# Out:
# Extracted 6782 documents

# %%
extracted_df.set_index("id").loc['KM1053350']
# Out:
# source_file                               content_tridion_end/KM1053350.html
# title                      Waarom krijg ik in 2025 meer/minder huurtoesla...
# private_answer_html        <p><strong>Meer/minder huurtoeslag t.o.v. vori...
# private_answer_text        Meer/minder huurtoeslag t.o.v. vorig jaar?\nDe...
# publicAnswer_html
# publicAnswer_text
# links_in_private_answer                                                   []
# full_text                  Public Answer:  Private Answer: Meer/minder hu...
# tags                       [Tridion (oud), 02. Hoogte toeslag, 02. Hoogte...
# km_nummer                                                          KM1053350
# Name: KM1053350, dtype: object

# %%
extracted_df.to_pickle(paths.content_folder /"extracted_df_km.pkl",compression='gzip')
